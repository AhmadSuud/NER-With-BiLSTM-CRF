# %%
! pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
! pip install Stopword
# Out:
# Collecting Stopword
#   Downloading stopword-0.0.4-py3-none-any.whl (14 kB)
# Installing collected packages: Stopword
# Successfully installed Stopword-0.0.4

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import pandas as pd

df = pd.read_csv('dfscrap1-2k.csv')

# %%
start_number = 1

# %%
df['Artikel'] = 'Artikel' + (df.index + start_number).astype(str)

# %%
df
# Out:
#                                              Rangkuman    Tanggal publikasi  \
# 0    Ketua KPU Provinsi DKI Jakarta, Wahyu Dinata, ...  2024-02-24 13:53:45
# 1    Pemungutan suara lanjutan di TPS 147 di Kelura...  2024-02-24 13:51:09
# 2    Wakil Presiden (Wapres) ke-10 dan ke-12 RI, Ju...  2024-02-24 12:58:42
# 3    Pemungutan suara lanjutan di TPS 147 di Kelura...  2024-02-24 11:15:30
# 4    Ridwan Kamil kembali jadi pusat perhatian usai...  2024-02-24 11:00:33
# ..                                                 ...                  ...
# 202  Presiden Joko Widodo (Jokowi) resmi melantik M...  2024-02-21 11:58:12
# 203  KPU masih melakukan penghitungan suara atau re...  2024-02-21 11:49:19
# 204  Anggota Komisi II DPR RI Fraksi PKS Mardani Al...  2024-02-21 11:38:15
# 205  AHY terlihat memberi hormat kepada Presiden Jo...  2024-02-21 11:31:44
# 206  Presiden Joko Widodo (Jokowi) kembali melakuka...  2024-02-21 11:14:24
#
#                      Sumber      Artikel
# 0    https://news.detik.com   Artikel996
# 1    https://news.detik.com   Artikel997
# 2    https://news.detik.com   Artikel998
# 3    https://news.detik.com   Artikel999
# 4     https://www.detik.com  Artikel1000
# ..                      ...          ...
# 202  https://news.detik.com  Artikel1198
# 203   https://www.detik.com  Artikel1199
# 204  https://news.detik.com  Artikel1200
# 205  https://news.detik.com  Artikel1201
# 206  https://news.detik.com  Artikel1202
#
# [207 rows x 4 columns]

# %%
from textblob import TextBlob
from wordcloud import WordCloud
import numpy as np
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

class preprocess:
    def low(self, data):
        return data.lower()

    # def del_num(self, data):
    #     data = re.sub(r"\d", "", data)
    #     return data

    # def del_punct(self, data):
    #     data = re.sub(r'#', '', data)
    #     data = re.sub(r'@[A-Za-z0-9]+', '', data)
    #     data = re.sub(r'#', '', data)
    #     data = re.sub(r'rt[\s]+', '', data)
    #     data = re.sub(r'https?:\/\/\S+', '', data)
    #     data = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", data)
    #     return data

    # def del_ws(self, data):
    #     return data.strip()

      # def del_stopword(self, data):
      #     stop_words_add = ['advertisement', 'scroll', 'to', 'continue', 'with', 'content', '--']
      #     word_tokens = word_tokenize(data)
      #     data = ' '.join([w for w in word_tokens if not w in stop_words_add])
      #     return data

    # def del_stopword2(self, data):
    #     stop_words = set(stopwords.words('indonesian'))
    #     word_tokens = word_tokenize(data)
    #     data = ' '.join([w for w in word_tokens if not w in stop_words])
    #     return data

    # def stemming(self, data):
    #     factory = StemmerFactory()
    #     stemmer = factory.create_stemmer()
    #     data = stemmer.stem(data)
    #     return data

    def tokenezing(self, data):
        return word_tokenize(data)

    def proses_1(self, data):
        data = self.low(data)
        # data = self.del_num(data)
        # data = self.del_punct(data)
        # data = self.del_ws(data)
        data = self.del_stopword(data)
        # data = self.del_stopword2(data)
        # data = self.stemming(data)
        return data

# %%
df['Rangkuman'] = df['Rangkuman'].apply(lambda x:preprocess().proses_1(x))

# %%
df
# Out:
#                                              Rangkuman    Tanggal publikasi  \
# 0    ketua kpu provinsi dki jakarta , wahyu dinata ...  2024-02-24 13:53:45
# 1    pemungutan suara lanjutan di tps 147 di kelura...  2024-02-24 13:51:09
# 2    wakil presiden ( wapres ) ke-10 dan ke-12 ri ,...  2024-02-24 12:58:42
# 3    pemungutan suara lanjutan di tps 147 di kelura...  2024-02-24 11:15:30
# 4    ridwan kamil kembali jadi pusat perhatian usai...  2024-02-24 11:00:33
# ..                                                 ...                  ...
# 202  presiden joko widodo ( jokowi ) resmi melantik...  2024-02-21 11:58:12
# 203  kpu masih melakukan penghitungan suara atau re...  2024-02-21 11:49:19
# 204  anggota komisi ii dpr ri fraksi pks mardani al...  2024-02-21 11:38:15
# 205  ahy terlihat memberi hormat kepada presiden jo...  2024-02-21 11:31:44
# 206  presiden joko widodo ( jokowi ) kembali melaku...  2024-02-21 11:14:24
#
#                      Sumber      Artikel
# 0    https://news.detik.com   Artikel996
# 1    https://news.detik.com   Artikel997
# 2    https://news.detik.com   Artikel998
# 3    https://news.detik.com   Artikel999
# 4     https://www.detik.com  Artikel1000
# ..                      ...          ...
# 202  https://news.detik.com  Artikel1198
# 203   https://www.detik.com  Artikel1199
# 204  https://news.detik.com  Artikel1200
# 205  https://news.detik.com  Artikel1201
# 206  https://news.detik.com  Artikel1202
#
# [207 rows x 4 columns]

# %%
data = df[['Artikel','Rangkuman']]

# %%
df1 = data

# %%
df1
# Out:
#          Artikel                                          Rangkuman
# 0     Artikel996  ketua kpu provinsi dki jakarta , wahyu dinata ...
# 1     Artikel997  pemungutan suara lanjutan di tps 147 di kelura...
# 2     Artikel998  wakil presiden ( wapres ) ke-10 dan ke-12 ri ,...
# 3     Artikel999  pemungutan suara lanjutan di tps 147 di kelura...
# 4    Artikel1000  ridwan kamil kembali jadi pusat perhatian usai...
# ..           ...                                                ...
# 202  Artikel1198  presiden joko widodo ( jokowi ) resmi melantik...
# 203  Artikel1199  kpu masih melakukan penghitungan suara atau re...
# 204  Artikel1200  anggota komisi ii dpr ri fraksi pks mardani al...
# 205  Artikel1201  ahy terlihat memberi hormat kepada presiden jo...
# 206  Artikel1202  presiden joko widodo ( jokowi ) kembali melaku...
#
# [207 rows x 2 columns]

# %%
df1.to_csv('bersih1-2k.csv', index=False)
